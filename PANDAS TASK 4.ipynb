# %% [markdown]
# a. Kindly fill the missing values with
#
# value
#
# Statistical value
#
# Filling method
#
# B) Create pivot table for position and average salary.
#
# C) Group the data using group by as per gender and average age.

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\91832\Downloads\ethnic_diversity.xlsx")

# %%
df
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %%
df.isnull().sum()
# Out:
# Employee_Name        0
# EmpID                0
# Position             3
# State                2
# Zip                  2
# Gender               7
# MaritalDesc          9
# CitizenDesc          3
# EmploymentStatus     0
# Department           5
# Salaries            12
# age                  0
# Race                 9
# dtype: int64

# %%
df['Position'].isnull().sum()
# Out:
# 3

# %%
df['Position'].fillna(df['Position'].mode()[0],inplace = True)

# %%
df['Position'].isnull().sum()
# Out:
# 0

# %%
df['State'].isnull().sum()
# Out:
# 2

# %%
df['State'].fillna(df['State'].mode()[0],inplace = True)

# %%
df['State'].isnull().sum()
# Out:
# 0

# %%
df['Zip'].isnull().sum()
# Out:
# 2

# %%
df['Zip'].fillna(df['Zip'].median,inplace = True)
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\2984127625.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<bound method Series.median of 0      1450.0
# 1      1460.0
# 2      2703.0
# 3      2170.0
# 4      2330.0
#         ...
# 305    6033.0
# 306    2169.0
# 307    1545.0
# 308    6278.0
# 309    2453.0
# Name: Zip, Length: 310, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Zip'].fillna(df['Zip'].median,inplace = True)

# %%
df['Zip'].isnull().sum()
# Out:
# 0

# %%
df['Gender'].isnull().sum()
# Out:
# 7

# %%
df['Gender'].fillna(method = 'ffill',inplace = True)
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\23579445.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Gender'].fillna(method = 'ffill',inplace = True)

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df['MaritalDesc'].isnull().sum()
# Out:
# 9

# %%
df['MaritalDesc'].fillna(method = 'bfill',inplace = True)
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\3532265294.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['MaritalDesc'].fillna(method = 'bfill',inplace = True)

# %%
df['MaritalDesc'].isnull().sum()
# Out:
# 0

# %%
df['CitizenDesc'].isnull().sum()
# Out:
# 3

# %%
df['CitizenDesc'].fillna('US Citizen',inplace = True)

# %%
df['CitizenDesc'].isnull().sum()
# Out:
# 0

# %%
df['Department'].isnull().sum()
# Out:
# 5

# %%
df['Department'].fillna(method = 'bfill',inplace = True)
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\1251912497.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Department'].fillna(method = 'bfill',inplace = True)

# %%
df.isnull().sum()
# Out:
# Employee_Name        0
# EmpID                0
# Position             0
# State                0
# Zip                  0
# Gender               0
# MaritalDesc          0
# CitizenDesc          0
# EmploymentStatus     0
# Department           0
# Salaries            12
# age                  0
# Race                 9
# dtype: int64

# %%
df['Department'].fillna(method = 'bfill',inplace = True)
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\1251912497.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Department'].fillna(method = 'bfill',inplace = True)

# %%
df['Race'].fillna(method = 'bfill',inplace = True)
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\2273336651.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Race'].fillna(method = 'bfill',inplace = True)

# %%
df.isnull().sum()
# Out:
# Employee_Name        0
# EmpID                0
# Position             0
# State                0
# Zip                  0
# Gender               0
# MaritalDesc          0
# CitizenDesc          0
# EmploymentStatus     0
# Department           0
# Salaries            12
# age                  0
# Race                 0
# dtype: int64

# %%
 df[(df['Position'] =='Administrative Assistant') &(df['Salaries'].isnull())].fillna(61089.35,inplace = True)
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\1775279694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[(df['Position'] =='Administrative Assistant') &(df['Salaries'].isnull())].fillna(61089.35,inplace = True)

# %%
df
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %%
df['Salaries'][3] = 61089.35
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\1442031815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][3] = 61089.35

# %%
df
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %%
df[df['Salaries'].isnull()]
# Out:
#              Employee_Name       EmpID                 Position State  \
# 21            Costa, Latia  1409070567       Area Sales Manager    CA
# 35   Westinghouse, Matthew  1009919990             BI Developer    MA
# 53         Bramante, Elisa  1006020066   Director of Operations    MA
# 65          Cisco, Anthony  1102024173               IT Support    MA
# 86        Sullivan, Kissy   1405067298       Production Manager    MA
# 101     Theamstern, Sophia  1404066739  Production Technician I    MA
# 120          Cockel, James  1599991009  Production Technician I    MA
# 134    Beatrice, Courtney   1403066194  Production Technician I    MA
# 148   Barone, Francesco  A  1101023679  Production Technician I    MA
# 169      Heitzman, Anthony  1002017900  Production Technician I    MA
# 190        Rossetti, Bruno  1405067492  Production Technician I    MA
#
#          Zip Gender MaritalDesc          CitizenDesc        EmploymentStatus  \
# ...

# %%
df['Salaries'][21] = 55990.4
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\4241347556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][21] = 55990.4

# %%
df
# Out:
#               Employee_Name       EmpID                  Position State  \
# 0                Brown, Mia  1103024456              Accountant I    MA
# 1      LaRotonda, William    1106026572              Accountant I    MA
# 2          Steans, Tyrone    1302053333              Accountant I    MA
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA
# 4               Singh, Nan   1307059817  Administrative Assistant    MA
# ..                      ...         ...                       ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA
# 308              South, Joe  1308060959      Sr. Network Engineer    CT
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA
#
#         Zip Gender MaritalDesc CitizenDesc      EmploymentStatus  \
# ...

# %%
df.pivot_table(index = 'Position',values = 'Salaries',aggfunc = 'median')
# Out:
#                                Salaries
# Position
# Accountant I                    674.280
# Administrative Assistant      61089.350
# Area Sales Manager            36485.250
# BI Developer                  33231.010
# BI Director                    4160.000
# CIO                           26418.010
# Data Analyst                  40083.520
# Data Analyst                  42304.750
# Data Architect                90016.010
# Database Administrator        33102.770
# Director of Sales             27595.700
# Enterprise Architect           5802.000
# IT Director                   36741.000
# IT Manager - DB               49791.240
# IT Manager - Infra             8997.890
# IT Manager - Support           2143.580
# IT Support                    39232.000
# Network Engineer              32278.400
# President & CEO               52633.500
# Principal Data Architect      24828.700
# Production Manager            43967.480
# Production Technician I       35819.025
# ...

# %%
df[df['Salaries'].isnull()]
# Out:
#              Employee_Name       EmpID                 Position State     Zip  \
# 35   Westinghouse, Matthew  1009919990             BI Developer    MA  2134.0
# 53         Bramante, Elisa  1006020066   Director of Operations    MA  2030.0
# 65          Cisco, Anthony  1102024173               IT Support    MA  2135.0
# 86        Sullivan, Kissy   1405067298       Production Manager    MA  1776.0
# 101     Theamstern, Sophia  1404066739  Production Technician I    MA  2066.0
# 120          Cockel, James  1599991009  Production Technician I    MA  2452.0
# 134    Beatrice, Courtney   1403066194  Production Technician I    MA  1915.0
# 148   Barone, Francesco  A  1101023679  Production Technician I    MA  1810.0
# 169      Heitzman, Anthony  1002017900  Production Technician I    MA  2149.0
# 190        Rossetti, Bruno  1405067492  Production Technician I    MA  2155.0
#
#     Gender MaritalDesc          CitizenDesc        EmploymentStatus  \
# ...

# %%
df['Salaries'][35] = 33231.010
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\968116300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][35] = 33231.010

# %%
df['Salaries'][53]  = 90000.0
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\3491927350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][53]  = 90000.0

# %%
df['Salaries'][65] = 39232.000
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\28174408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][65] = 39232.000

# %%
df['Salaries'][86] = 43967.480
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\419682109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][86] = 43967.480

# %%
df['Salaries'][101]  = 35819.025
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\2206094773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][101]  = 35819.025

# %%
df['Salaries'][120]  = 35819.025
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\2931504674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][120]  = 35819.025

# %%
df['Salaries'][134]  = 35819.025
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\2176451882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][134]  = 35819.025

# %%
df['Salaries'][148]  = 35819.025
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\3818148413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][148]  = 35819.025

# %%
df['Salaries'][169]  = 35819.025
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\3817572689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][169]  = 35819.025

# %%
df['Salaries'][190]  = 35819.025
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_18456\1927222689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salaries'][190]  = 35819.025

# %%
df.isnull().sum()
# Out:
# Employee_Name       0
# EmpID               0
# Position            0
# State               0
# Zip                 0
# Gender              0
# MaritalDesc         0
# CitizenDesc         0
# EmploymentStatus    0
# Department          0
# Salaries            0
# age                 0
# Race                0
# dtype: int64

# %%
df.pivot_table(index = 'Position',values = 'Salaries',aggfunc= 'median')
# Out:
#                                Salaries
# Position
# Accountant I                    674.280
# Administrative Assistant      61089.350
# Area Sales Manager            36485.250
# BI Developer                  33231.010
# BI Director                    4160.000
# CIO                           26418.010
# Data Analyst                  40083.520
# Data Analyst                  42304.750
# Data Architect                90016.010
# Database Administrator        33102.770
# Director of Operations        90000.000
# Director of Sales             27595.700
# Enterprise Architect           5802.000
# IT Director                   36741.000
# IT Manager - DB               49791.240
# IT Manager - Infra             8997.890
# IT Manager - Support           2143.580
# IT Support                    39232.000
# Network Engineer              32278.400
# President & CEO               52633.500
# Principal Data Architect      24828.700
# Production Manager            43967.480
# ...

# %%
df.groupby(by = 'Gender')['age'].mean()
# Out:
# Gender
# F     38.659091
# M     38.746269
# Name: age, dtype: float64
